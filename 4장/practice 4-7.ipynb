# %% [markdown]
# ## 알고리즘 4장 연습 문제 7번

# %% [markdown]
# 7. 다음의 방향 그래프에 대해 DFS 기반 위상 정렬을 수행하라. (교재 그림 참고)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 답: A->B->C->D->E->F->G

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 답: A->B->C->E->G->H->D->F
