# %% [markdown]
# ## 알고리즘 예제4.5

# %% [markdown]
# 문제 정의 : 이진 탐색(순환구조)

# %% [markdown]
# 알고리즘 설명
#
# 1. binary_search(A, key, low, high)함수에는 정렬된 리스트 A와 킷값 key, 그리고 리스트 내의 탐색 범위인 low와 high가 입력된다.
#
# 2. low와 high가 역전되지 않으면, 아직 탐색할 영역이 남은 경우이다.
#
# 3. mid를 계산해 그 항목(A[mid])이 key와 같으면 탐색 성공이다.
#
# 4. A[mid]가 key보다 큰 경우와 작은 경우에 대해 각각 왼쪽과 오른쪽 부분 리스트를 순환적으로 탐색한다. (순환호출의 인덱스에 유의할 것)
#
# 5. 모든 탐색이 실패하면 -1을 반환한다.

# %% [markdown]
# 손으로 푼 예제 :
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 코드 개요 : 이진 탐색 함수(순환구조) (binary_search(A, key, low, high))
#
# 입력 변수 : listA
#
# 출력 변수 : binary_search(listA, 50, 0, len(listA)-1), binary_search(listA, 2, 0, len(listA)-1)|

# %%
#알고리즘 코드

def binary_search(A, key, low, high) :
    if (low <= high) :
        mid = (low + high) // 2
        if key == A[mid] :
            return mid
        elif key < A[mid] :
            return binary_search(A, key, low, mid-1)
        else :
            return binary_search(A, key, mid+1, high)
    return -1

# %%
#테스트 코드

listA = [1, 4, 7, 12, 15, 15, 25, 28, 30, 33, 40, 47, 50, 77]
print("입력 리스트 =", listA)
print("50 탐색(순환) -->", binary_search(listA, 50, 0, len(listA)-1) )
print("2 탐색(순환) -->", binary_search(listA, 2, 0, len(listA)-1) )
# Out:
# 입력 리스트 = [1, 4, 7, 12, 15, 15, 25, 28, 30, 33, 40, 47, 50, 77]
# 50 탐색(순환) --> 12
# 2 탐색(순환) --> -1

# %% [markdown]
# 수행 결과
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 복잡도 분석
#
# T(n) = T([n/2]+1)= 1+ k 이므로 O(k)이다. 이때, n = 2^k이므로 O(log2(n))이 된다.
